# %%
import pandas as pd
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv("jobs_KCS_Sep14.csv")

# %%
df
# Out:
#                                                  title               Location  \
# 0            TRANSPORTATION RADIO DISPATCHER TIME CARD         TRANSPORTATION
# 1    ASSISTANT SOFTBALL COACH / EXTRA / FULTON HIGH...            FULTON HIGH
# 2                           EDUC ASSIST CDC MS 23/24SY            VINE MIDDLE
# 3    STRENGTH AND CONDITIONING COACH / HARDIN VALLE...  HARDIN VALLEY ACADEMY
# 4    ASSISTANT FOOTBALL COACH / SOUTH DOYLE HIGH SC...       SOUTH DOYLE HIGH
# ..                                                 ...                    ...
# 373                        EDUC ASSIST SPED HS 23/24SY           CENTRAL HIGH
# 374                  SUBSTITUTE APPLICANT POOL 23/24SY             SUBSTITUTE
# 375                        EDUC ASSIST TITLE 1 23/24SY   EAST KNOX ELEMENTARY
# 376          TCHR LANG ARTS HS SUPPLY THROUGH 12/20/23            FULTON HIGH
# 377                                  MAINT MOWING CREW            MAINTENANCE
#
# ...
